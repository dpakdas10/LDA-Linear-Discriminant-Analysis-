# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
import matplotlib.pyplot as plt

# Load the iris dataset
iris = datasets.load_iris()
X = iris.data  # Features
y = iris.target  # Target (class labels)

print("Number of samples:", X.shape[0])
print("Number of features:", X.shape[1])
print("Number of classes:", len(set(y)))
# Out:
# Number of samples: 150
# Number of features: 4
# Number of classes: 3

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Print the mean and standard deviation of the scaled data
print("Mean of scaled data:", np.mean(X_scaled, axis=0))
print("Standard deviation of scaled data:", np.std(X_scaled, axis=0))
# Out:
# Mean of scaled data: [-1.69031455e-15 -1.84297022e-15 -1.69864123e-15 -1.40924309e-15]
# Standard deviation of scaled data: [1. 1. 1. 1.]

# %%
# Scatter plot of sepal length vs sepal width with class labels
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.colorbar(label='Class Label')
plt.show()

# Scatter plot of petal length vs petal width with class labels
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 2], X[:, 3], c=y, cmap='viridis')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Scatter Plot of Petal Length vs Petal Width')
plt.colorbar(label='Class Label')
plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Apply LDA with 2 components
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

# Print the explained variance ratio
print("Explained variance ratio:", lda.explained_variance_ratio_)

# Scatter plot of the reduced data with class labels
plt.figure(figsize=(8, 6))
plt.scatter(X_lda[:, 0], X_lda[:, 1], c=y, cmap='viridis')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.title('Scatter Plot of LDA Components')
plt.colorbar(label='Class Label')
plt.show()
# Out:
# Explained variance ratio: [0.9912126 0.0087874]

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA

# Load the iris dataset
iris = datasets.load_iris()
X = iris.data  # Features
y = iris.target  # Target (class labels)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA with 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Apply LDA with 2 components
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

# Scatter plot of PCA components with class labels
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Scatter Plot of PCA Components')
plt.colorbar(label='Class Label')
plt.show()

# Scatter plot of LDA components with class labels
plt.figure(figsize=(8, 6))
plt.scatter(X_lda[:, 0], X_lda[:, 1], c=y, cmap='viridis')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.title('Scatter Plot of LDA Components')
plt.colorbar(label='Class Label')
plt.show()
